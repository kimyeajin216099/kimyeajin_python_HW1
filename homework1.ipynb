# %%
situation=int(input("1:추가, 2:삭제, 3:종료-->"))
while situation!=3:
    
    if situation==1:
        insertArray()
        print
        
    
    
    elif situaion==2:
        deleteArray()
        print
    
    else:
        print("번호를 잘못 입력하였습니다.")
        
        
        
        
        
def insertArray():
    df

    return

def deleteArray():
    return
# Out:
# 1:추가, 2:삭제, 3:종료-->1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       2 while situation!=3:
#       4     if situation==1:
# ----> 5         insertArray()
#       6         print
#      10     elif situaion==2:
#
# NameError: name 'insertArray' is not defined

# %%
class Node():
    def __init__(self):
        self.data=None
        self.link=None
        
def insertNode(addData):
    global memory,head,current,pre
    
    node=Node()
    node.data=addData
    current.link=node
        
def printNodes(start):
    current=start
    if current==None:
        return
    print(current.data,end='')
    
    while current.link!=None:
        current=current.link
        print(current.data,end='')
    print()
    
    
def makeSimpleList(name):
    global memory,head,current,pre
    printNodes(head)
    node=Node()
    node.data=name
    memory.append(node)
    if head==None:
        head=node
        return
    if head.data[1]<name[1]:
        node.link=head
        head=node
        return
    
    current=head
    while current.link!=None:
        pre=current
        current=current.link
        if current.data[1]<name[1]:
            pre.link=node
            node.link=current
            return
    current.link=node
    print(memory)

    
memory=[]

head,current,pre=None,None,None
dataArray=[["지민","111"],["ㄱㄱ국","322"],["ㄱㄴ","4562"]]

if __name__=="__main__":
    
    for data in memory:
        makeSimpleList(data)
        
    printNodes(head)

# %%
class Node():
    def __init__(self):
        self.data=None
        self.link=None
        
def insertNode(addData):
    global memory,head,current,pre
    
    node=Node()
    node.data=addData
    
    memory.append(node)
    
    if head==None:
        head=node
        return
    
    if head.data[1]<addData[1]:
        node.link=head
        head=node
        return
        
def printNodes(start):
    current=start
    if current==None:
        return
    print(current.data,end='')
    
    while current.link!=None:
        current=current.link
        print(current.data,end='')
    print()
    
    
def makeSimpleList(name):
    global memory,head,current,pre
    printNodes(head)
    node=Node()
    node.data=name
    memory.append(node)
    if head==None:
        head=node
        return
    if head.data[1]<name[1]:
        node.link=head
        head=node
        return
    
    current=head
    while current.link!=None:
        pre=current
        current=current.link
        if current.data[1]<name[1]:
            pre.link=node
            node.link=current
            return
    current.link=node

    
memory=[]

head,current,pre=None,None,None
dataArray=[["지민","111"],["ㄱㄱ국","322"],["ㄱㄴ","4562"]]

if __name__=="__main__":
    
    for data in dataArray:
        makeSimpleList(data)
        
    printNodes(head)
# Out:
# ['지민', '111']
# ['ㄱㄱ국', '322']['지민', '111']
# ['ㄱㄴ', '4562']['ㄱㄱ국', '322']['지민', '111']

# %%
class Node():
    def __init__(self):
        self.data=None
        self.link=None
        
def insertNode(addData):
    global memory,head,current,pre
    
    node=Node()
    node.data=addData
    
    
    if head==None:
        node.link=head
        head=node
        return
    current=head
    
    while current.link!=None:
        pre=current
        current=current.link
        if current.data[1]<addData[1]:
            node.link=current
            pre.link=node
        return
    
    current.link=node
        
def printNodes(start):
    current=start
    if current==None:
        return
    print(current.data,end='')
    
    while current.link!=None:
        current=current.link
        print(current.data,end='')
    print()
    
    
def makeSimpleList(name):
    global memory,head,current,pre
    printNodes(head)
    node=Node()
    node.data=name
    memory.append(node)
    if head==None:
        head=node
        return
    if head.data[1]<name[1]:
        node.link=head
        head=node
        return
    
    current=head
    while current.link!=None:
        pre=current
        current=current.link
        if current.data[1]<name[1]:
            pre.link=node
            node.link=current
            return
    current.link=node

    
memory=[]

head,current,pre=None,None,None
dataArray=[["지민","111"],["ㄱㄱ국","322"],["ㄱㄴ","4562"]]

if __name__=="__main__":
    
    for data in dataArray:
        makeSimpleList(data)
        
    printNodes(head)

# %%
class Node():
    def __init__(self):
        self.data=None
        self.link=None
        
def insertNode(addData):
    global memory,head,current,pre
    
    node=Node()
    node.data=addData
    
    if head==None:
        node.link=head
        head=node
        print("1")
        return
    
    current=head
    while current.link!=None:
        pre=current
        current=current.link
        print("2")
        if current.data[1]<addData[1]:
            print("3")
            node.link=current
            pre.link=node
            return
    
    print("4")
    current.link=node
    print("5")
 
        
def printNodes(start):
    current=start
    if current==None:
        return
    print(current.data,end='')
    
    while current.link!=None:
        current=current.link
        print(current.data,end='')
    print()
    

memory=[]

head,current,pre=None,None,None
dataArray=[]

if __name__=="__main__":
    global dataArray
   
    insertNode(["가현",200]) 
    printNodes(head)
    
    insertNode(["나현",300]) 
    printNodes(head)
    
    insertNode(["다현",100])
    printNodes(head)
    
    insertNode(["라현",400]) 
    printNodes(head)
