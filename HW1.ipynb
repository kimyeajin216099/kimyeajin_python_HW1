# %%
class Node():
    def __init__(self):
        self.data=None
        self.link=None

def insertNode(addData):
    global memory,head,current,pre
    
    node=Node()
    node.data=addData
    
    if head==None:
        node.link=head
        head=node
        print("1")
        return
    
    current=head
    while current.link!=None:
        pre=current
        current=current.link
        print("2")
        if current.data[1]<addData[1]:
            print("3")
            node.link=current
            pre.link=node
            return
    
    print("4")
    current.link=node
    print("5")
 
        
    
def deleteNumber(number):
    global memory,head,current,pre
    
    current=head
    if number==1:
        head=current.link
        del (current)
        return
    
    for i in range(0,number-1,1):
        pre=current
        current=current.link
    
    pre.link=current.link
    del(current)
    return
   
        
    
    
def printNodes(start):
    current=start
    if current==None:
        return
    print(current.data,end='')
    
    while current.link!=None:
        current=current.link
        print(current.data,end='')
    print()
    

memory=[]

head,current,pre=None,None,None
dataArray=[]

if __name__=="__main__":
    global dataArray
    situation=0
    
    while situation!=3:
        situation=int(input("1:추가, 2:삭제, 3:종료-->"))
        if situation==1:
            addData=eval(input("추가할 데이터-->"))
            insertNode(addData)
            printNodes(head)
            
        
        elif situation==2:
            deleteData=int(input("삭제할 데이터-->"))
            deleteNumber(deleteData)
            printNodes(head)
            
    
        else:
            if situation!=3:
                print("번호를 잘못 입력하였습니다.")

# %% [markdown]
# ![connect.jpeg](attachment:connect.jpeg)

# %% [markdown]
# ![IDE.JPG](attachment:IDE.JPG)
